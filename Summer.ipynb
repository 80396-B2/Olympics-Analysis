# %% [markdown]
# # Summer Olympics Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("summer.csv")
sns.set_style("white")
sns.set_style("ticks")
# %matplotlib inline
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
print("Summer Olympics have been held in",len(df["City"].unique()),"cities so far!!")
# Out:
# Summer Olympics have been held in 22 cities so far!!

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df[df["Medal"]=="Gold"]["Sport"].value_counts().head().plot.bar(figsize = (10,6),color="green")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Sports with Most Gold Medals",size=20)
plt.xlabel("\nName of the Sport",size=20)
plt.ylabel("Number of Medals",size=20)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df["Sport"].value_counts().head().plot.bar(figsize = (10,7),color="purple")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Sports with Most Medals",size=20)
plt.xlabel("\nSport Name",size=20)
plt.ylabel("Number of Medals",size=20)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df["Athlete"].value_counts().head().plot.bar(figsize = (10,6),color="maroon")
plt.xticks(rotation=15, horizontalalignment="center",size=13)
plt.yticks(np.arange(0,24,step=2),size=15)
plt.title("Player with Most Medals",size=20)
plt.xlabel("\nPlayer Name",size=20)
plt.ylabel("Number of Medals",size=20)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df[df["Medal"]=="Gold"]["Athlete"].value_counts().head().plot.bar(figsize = (13,8),color="green")
plt.xticks(rotation=0, horizontalalignment="center",size=13)
plt.yticks(np.arange(0, 19, step=2),size=15)
plt.title("Player with Most Gold Medals",size=20)
plt.xlabel("\nPlayer Name",size=20)
plt.ylabel("Number of Medals",size=20)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
print("India won it's first ever Gold Medal in the year:",*df[(df["Medal"]=="Gold") &(df["Country"]=="IND")]["Year"].head(1).tolist())
# Out:
# India won it's first ever Gold Medal in the year: 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df["Event"].value_counts().head().plot.bar(figsize = (10,6),color="brown")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Most Popular Event",size=20)
plt.xlabel("\nEvent Name",size=20)
plt.ylabel("Number of Players",size=20)
# Out:
# Text(0, 0.5, 'Number of Players')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df[(df["Medal"]=="Gold")&(df["Gender"]=="Women")]["Sport"].value_counts().head().plot.bar(figsize = (10,6),color="black")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Female Gold Medalist",size=20)
plt.xlabel("\nSport Name",size=20)
plt.ylabel("Number of Medals",size=20)
# Out:
# Text(0, 0.5, 'Number of Medals')
